# %% [markdown]
# Estaturas

# %%
archi <- read.csv("numeros_aleatorios.csv", header = FALSE)

# %%
alturas <- read.csv("numeros_estaturas_R1.csv", header = FALSE)

# %%
hist(archi$V1, ylim = c(0,15),labels = T, border="white",col = "red", ylab = "FRECUENCIA", xlab = "", main = "90 aleatoriosLehmer")
# Out:
# Plot with title "90 aleatoriosLehmer"

# %%
hist(alturas$V1, ylim = c(0,30),labels = T, border="red",col = "pink", ylab = "FRECUENCIA", xlab = "", main = "Normalizados")
# Out:
# Plot with title "Normalizados"

# %% [markdown]
# Fin
